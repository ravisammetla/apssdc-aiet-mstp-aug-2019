# %% [markdown]
# # markdown introduction

# %% [markdown]
# # heading
# ## heading
# ### heading
# #### heading

# %% [markdown]
# **ravi**

# %% [markdown]
# ravi

# %% [markdown]
# *srkk*

# %% [markdown]
# <strike>sammetla</strike>

# %% [markdown]
# 'high light'

# %% [markdown]
# `highlight

# %% [markdown]
# `highlight`

# %% [markdown]
# hai<br> kumar

# %% [markdown]
# <img src="data:image/jpeg;base64,..." width="100px" height="100px">

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %%html
# <iframe width="697" height="392" src="https://www.youtube.com/embed/rfscVS0vtbw" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="697" height="392" src="https://www.youtube.com/embed/rfscVS0vtbw" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# * python
# * java
# * r programming
# * scripting languages
# - html
# - xml

# %% [markdown]
# # python programming

# %% [markdown]
# ## python introduction

# %%
print("ravi kumar")
print("apssdc")
# Out:
# ravi kumar
# apssdc

# %%
print(1)
# Out:
# 1

# %% [markdown]
# # operators

# %% [markdown]
# * arthematic operators
# * logical operators
# * relational operators
# * assignment operators
# * bit wise operators
# * identity operators
# * membership operators

# %% [markdown]
# ## arthematic operators

# %%
(10 + 1)
# Out:
# 11

# %%
(10-2)
# Out:
# 8

# %%
10 / 2
# Out:
# 5.0

# %%
10 //3
# Out:
# 3

# %%
10%3
# Out:
# 1

# %%
2**4
# Out:
# 16

# %%
2 pow 4
# Out:
#   File "<ipython-input-13-bddef1c79b5d>", line 1
#     2 pow 4
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### logical operators

# %%
True or False
# Out:
# True

# %%
True or True
# Out:
# True

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
True and False
# Out:
# False

# %% [markdown]
# ### relational operators

# %%
2==3
# Out:
# False

# %%
2!=3
# Out:
# True

# %%
2>4
# Out:
# False

# %%
3<5
# Out:
# True

# %%
3<=5
# Out:
# True

# %% [markdown]
# ### assignment operators

# %%
a=10
type(a)
# Out:
# int

# %%
a="hello"
type(a)
# Out:
# str

# %%
a=b=c=10

# %%
a,b,c
# Out:
# (10, 10, 10)

# %%
a,b,c=1,2,3

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
3
# Out:
# 3

# %%
c
# Out:
# 3

# %%
print(a,b,c)
# Out:
# 1 2 3

# %%
a,b=b,a

# %%
a,b
# Out:
# (2, 1)

# %%
a=1
a
# Out:
# 1

# %%
a=a+1

# %%
a
# Out:
# 2

# %%
a+=1
a
# Out:
# 3

# %%
a*=10
a
# Out:
# 30

# %%
a//=3
a
# Out:
# 3

# %%
a-=3
a
# Out:
# -3

# %% [markdown]
# ## bitwise operators

# %%
4&7
# Out:
# 4

# %%
7|4
# Out:
# 7

# %%
8<<2
# Out:
# 32

# %%
8>>2
# Out:
# 2

# %% [markdown]
# ## identity operators

# %%
2==3
# Out:
# False

# %%
2 is 3
# Out:
# False

# %%
2!=3
# Out:
# True

# %%
2 is not 3
# Out:
# True

# %% [markdown]
# ## membership operators

# %%
"ap" in "apssdc"
# Out:
# True

# %%
"Ap" in "apssdc"
# Out:
# False

# %%
"a" in "apssdc"
# Out:
# True

# %%
'p' in "apssdc"
# Out:
# True

# %%
"r" not in "apssdc"
# Out:
# True
